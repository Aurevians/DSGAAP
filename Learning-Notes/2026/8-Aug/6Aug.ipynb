# %% [markdown]
# ### 6th Aug 2026
# ---------------------------

# %% [markdown]
# #### Python Datatypes
# ==========================
# ##### * integer (int (number))
# ##### * float (flo (decimal))
# ##### * string (str (text))
# ##### * boolean (bool (True|False))
# ##### * complex (Real+Imaginary)
#
# #### integer (int (number))
# =============================

# %%
i = 5
i
# Out:
# 5

# %%
type()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 type()
#
# TypeError: type() takes 1 or 3 arguments

# %%
# Error because type() function takes either 1 or 3 arguments

# %%
type(i)
# Out:
# int

# %%
i
# Out:
# 5

# %%
id()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 id()
#
# TypeError: id() takes exactly one argument (0 given)

# %%
# Error because id() function takes only 1 but no argument is passed

# %%
id(i)
# Out:
# 4382957600

# %%
age=35
print(type(age))
print(id(age))
# Out:
# <class 'int'>
# 4382958560

# %%
p = 20
q = 20
print(id(p))
print(id(q))
# Out:
# 4382958080
# 4382958080

# %%
p = p + 10
q = 20
print(p, id(p))
print(q, id(q))
# Out:
# 30 4382958400
# 20 4382958080

# %% [markdown]
# #### float (flo (decimal))
# ==============================

# %%
f=1.5
print(type(f))
print(id(f))
# Out:
# <class 'float'>
# 4439978512

# %% [markdown]
# #### boolean (bool (True|False))
# ==================================

# %%
b=true
b
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 b=true
#       2 b
#
# NameError: name 'true' is not defined

# %%
b = True
b
# Out:
# True

# %%
print(type(b))
# Out:
# <class 'bool'>

# %%
b1=True
b2=False
print(type(b1))
print(type(b2))
print(id(b1), id(b2))
# Out:
# <class 'bool'>
# <class 'bool'>
# 4382943888 4382943856

# %%
print('value of b1 is ', b1)
print('value of b2 is ', b2)
print('value of b1+b2 is ', b1+b2 )
print('value of b1-b2 is ', b1-b2 )
print('value of b1*b2 is ', b1*b2 )
print('value of b2/b1 is ', b2/b1 )
print('value of b2//b1 is ', b2//b1 )
print('value of b1/b2 is ', b1/b2 )
# Out:
# value of b1 is  True
# value of b2 is  False
# value of b1+b2 is  1
# value of b1-b2 is  1
# value of b1*b2 is  0
# value of b2/b1 is  0.0
# value of b2//b1 is  0
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[24], line 8
#       4 print('value of b1-b2 is ', b1-b2 )
#       5 print('value of b1*b2 is ', b1*b2 )
#       6 print('value of b2/b1 is ', b2/b1 )
#       7 print('value of b2//b1 is ', b2//b1 )
# ----> 8 print('value of b1/b2 is ', b1/b2 )
#
# ZeroDivisionError: division by zero

# %%
# Error because we cannot devide a number by zero

# %% [markdown]
# #### complex (Real+Imaginary)
# =================================

# %%
c = 10 + 20j
print(c)
print(type(c))
print(id(c))
# Out:
# (10+20j)
# <class 'complex'>
# 4439979056

# %%
c = 10+20J
print(c)
print(c.real)
print(c.imag)
# Out:
# (10+20j)
# 10.0
# 20.0

# %%
c = 10 + 20k
print(c)
# Out:
#   Cell In[29], line 1
#     c = 10 + 20k
#               ^
# SyntaxError: invalid decimal literal

# %%
# Error because we can only use j or J for imaginary part of complex number

# %%
c1 = 10+20j
c2 = 20+30j
print(c1+c2)
print((c1+c2).real, (c1+c2).img)
# Out:
# (30+50j)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[37], line 4
#       1 c1 = 10+20j
#       2 c2 = 20+30j
#       3 print(c1+c2)
# ----> 4 print((c1+c2).real, (c1+c2).img)
#
# AttributeError: 'complex' object has no attribute 'img'

# %%
# Error because attribute of complex number is either 'real' or 'imag', any other attribute will give error.

# %%
c1 = 10+20j
c2 = 20+30j
print(c1+c2)
print((c1+c2).real, (c1+c2).imag)
# Out:
# (30+50j)
# 30.0 50.0

# %% [markdown]
# ### NOTES
# ------------------------------------
# #### Python Datatypes
# ==========================
# ##### * integer (int (number))
# ##### * float (flo (decimal))
# ##### * string (str (text))
# ##### * boolean (bool (True|False))
# ##### * complex (Real+Imaginary)
